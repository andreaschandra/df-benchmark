# %%
import pandas as pd

# %%
d_result = pd.read_csv('../data/result.csv')

# %%
d_result.shape
# Out:
# (10000000, 8)

# %%
d_result.head()
# Out:
#                                      job                        company  \
# 0  Emergency planning/management officer  Washington, Torres and Conner
# 1   English as a second language teacher                   Hudson-Woods
# 2  English as a foreign language teacher                    Moore-Pratt
# 3                                 Dealer                    Smith Group
# 4                      Minerals surveyor     Simmons, Horton and Martin
#
#            ssn blood_group              username sex  \
# 0  036-51-3780          B-        samanthafisher   F
# 1  197-91-9713          A+                fallen   F
# 2  226-31-0368          O-  whiteheadchristopher   M
# 3  041-74-2846          A+              wstewart   M
# 4  474-61-9160          O+             valerie23   M
#
#                           mail   birthdate
# 0         jaredlogan@yahoo.com  1925-05-15
# 1          chelsea15@yahoo.com  1987-11-13
# 2           zclayton@yahoo.com  1979-09-19
# ...

# %%
d_result.loc[0:3]
# Out:
#                                      job                        company  \
# 0  Emergency planning/management officer  Washington, Torres and Conner
# 1   English as a second language teacher                   Hudson-Woods
# 2  English as a foreign language teacher                    Moore-Pratt
# 3                                 Dealer                    Smith Group
#
#            ssn blood_group              username sex  \
# 0  036-51-3780          B-        samanthafisher   F
# 1  197-91-9713          A+                fallen   F
# 2  226-31-0368          O-  whiteheadchristopher   M
# 3  041-74-2846          A+              wstewart   M
#
#                           mail   birthdate
# 0         jaredlogan@yahoo.com  1925-05-15
# 1          chelsea15@yahoo.com  1987-11-13
# 2           zclayton@yahoo.com  1979-09-19
# 3  christophertorres@yahoo.com  1915-03-11

# %%
d_result.loc[i]
# Out:
#                                            job                        company  \
# 0        Emergency planning/management officer  Washington, Torres and Conner
# 1         English as a second language teacher                   Hudson-Woods
# 2        English as a foreign language teacher                    Moore-Pratt
# 3                                       Dealer                    Smith Group
# 4                            Minerals surveyor     Simmons, Horton and Martin
# ...                                        ...                            ...
# 9999995                        Learning mentor                    Smith-Cowan
# 9999996                      Personnel officer               Griffith-Johnson
# 9999997         Furniture conservator/restorer                      Jones LLC
# 9999998            Community education officer                    Pham-Wilson
# 9999999                    Designer, furniture    Pitts, Johnson and Trujillo
#
# ...

# %%
for batch, i in enumerate(range(0, 10000000, 1000000)):
    d_batch = d_result.loc[i:i+999999].copy()
    d_batch.to_csv(f'../data/batch-1M/batch_{batch}.csv', index=False)

# %%
for batch, i in enumerate(range(0, 10000000, 100000)):
    d_batch = d_result.loc[i:i+99999].copy()
    d_batch.to_csv(f'../data/batch-100K/batch_{batch}.csv', index=False)
